# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('FinancialMarketData_EWS.csv')

# %%
df.head()
# Out:
#    Y       Data  XAU BGNL  ECSURPUS    BDIY     CRY     DXY     JPY    GBP  \
# 0  0  1/11/2000    283.25     0.077  1388.0  157.26  100.56  105.86  1.646
# 1  0  1/18/2000    287.65     0.043  1405.0  165.01  101.86  105.47  1.638
# 2  0  1/25/2000    287.15     0.135  1368.0  167.24  102.41  106.04  1.650
# 3  0   2/1/2000    282.75     0.191  1311.0  166.85  104.92  107.85  1.611
# 4  1   2/8/2000    298.40     0.312  1277.0  165.43  104.22  109.30  1.611
#
#      Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU     MXJP    MXBR  \
# 0  25.77  ...   116.464   230.527   123.762  1416.12  127.75   990.59  856.76
# 1  28.85  ...   117.267   231.377   123.762  1428.79  129.50   993.98  925.22
# 2  28.28  ...   117.995   232.390   123.762  1385.93  126.48   974.83  886.93
# 3  28.22  ...   120.510   231.942   122.328  1385.31  129.19  1007.12  842.60
# 4  28.02  ...   118.791   237.812   122.328  1411.95  134.67  1034.58  945.15
#
#      MXRU    MXIN   MXCN
# ...

# %%
df.describe()
# Out:
#                  Y     XAU BGNL     ECSURPUS          BDIY          CRY  \
# count  1111.000000  1111.000000  1111.000000   1111.000000  1111.000000
# mean      0.213321   987.463744     0.036153   2259.860486   245.247670
# std       0.409837   494.623740     0.349453   2017.811888    68.278066
# min       0.000000   256.680000    -0.974000    291.000000   106.293000
# 25%       0.000000   433.740000    -0.191000    990.000000   184.705550
# 50%       0.000000  1137.800000     0.035000   1518.000000   234.560000
# 75%       0.000000  1324.825000     0.260500   2685.500000   301.539500
# max       1.000000  2006.910000     0.991000  11793.000000   467.570000
#
#                DXY          JPY          GBP          Cl1          VIX  ...  \
# count  1111.000000  1111.000000  1111.000000  1111.000000  1111.000000  ...
# mean     90.934982   106.605734     1.569661    60.708101    19.992169  ...
# std      11.379095    12.840754     0.212344    25.900813     8.642157  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 44 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Y          1111 non-null   int64
#  1   Data       1111 non-null   object
#  2   XAU BGNL   1111 non-null   float64
#  3   ECSURPUS   1111 non-null   float64
#  4   BDIY       1111 non-null   float64
#  5   CRY        1111 non-null   float64
#  6   DXY        1111 non-null   float64
#  7   JPY        1111 non-null   float64
#  8   GBP        1111 non-null   float64
#  9   Cl1        1111 non-null   float64
#  10  VIX        1111 non-null   float64
#  11  USGG30YR   1111 non-null   float64
#  12  GT10       1111 non-null   float64
#  13  USGG2YR    1111 non-null   float64
#  14  USGG3M     1111 non-null   float64
#  15  US0001M    1111 non-null   float64
#  16  GTDEM30Y   1111 non-null   float64
#  17  GTDEM10Y   1111 non-null   float64
#  18  GTDEM2Y    1111 non-null   float64
# ...

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Rename Data to Date
df.rename(columns={'Data': 'Date'}, inplace=True)

# %%
# convert Data to datetime type
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# %%
# sort the data by date
df = df.sort_values(by = 'Date')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 44 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Y          1111 non-null   int64
#  1   Date       1111 non-null   datetime64[ns]
#  2   XAU BGNL   1111 non-null   float64
#  3   ECSURPUS   1111 non-null   float64
#  4   BDIY       1111 non-null   float64
#  5   CRY        1111 non-null   float64
#  6   DXY        1111 non-null   float64
#  7   JPY        1111 non-null   float64
#  8   GBP        1111 non-null   float64
#  9   Cl1        1111 non-null   float64
#  10  VIX        1111 non-null   float64
#  11  USGG30YR   1111 non-null   float64
#  12  GT10       1111 non-null   float64
#  13  USGG2YR    1111 non-null   float64
#  14  USGG3M     1111 non-null   float64
#  15  US0001M    1111 non-null   float64
#  16  GTDEM30Y   1111 non-null   float64
#  17  GTDEM10Y   1111 non-null   float64
#  18  GTDEM2Y    1111 non-null   float64
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Y       Date  XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY  \
# 0     0 2000-01-11    283.25     0.077  1388.0  157.2600  100.560  105.86
# 1     0 2000-01-18    287.65     0.043  1405.0  165.0100  101.860  105.47
# 2     0 2000-01-25    287.15     0.135  1368.0  167.2400  102.410  106.04
# 3     0 2000-02-01    282.75     0.191  1311.0  166.8500  104.920  107.85
# 4     1 2000-02-08    298.40     0.312  1277.0  165.4300  104.220  109.30
# ...  ..        ...       ...       ...     ...       ...      ...     ...
# 1106  0 2021-03-23   1727.96     0.339  2271.0  184.5022   92.336  108.72
# 1107  0 2021-03-30   1685.56     0.303  2103.0  184.8741   93.297  110.29
# 1108  0 2021-04-06   1743.28     0.440  2092.0  185.8393   92.335  109.88
# 1109  0 2021-04-13   1742.69     0.467  2140.0  188.1368   91.852  109.19
# 1110  0 2021-04-20   1779.72     0.492  2432.0  193.8035   91.147  108.09
#
#          GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU  \
# ...

# %%
# Add month column
df['Month'] = df['Date'].dt.month

# %%
df
# Out:
#       Y       Date  XAU BGNL  ECSURPUS    BDIY       CRY      DXY     JPY  \
# 0     0 2000-01-11    283.25     0.077  1388.0  157.2600  100.560  105.86
# 1     0 2000-01-18    287.65     0.043  1405.0  165.0100  101.860  105.47
# 2     0 2000-01-25    287.15     0.135  1368.0  167.2400  102.410  106.04
# 3     0 2000-02-01    282.75     0.191  1311.0  166.8500  104.920  107.85
# 4     1 2000-02-08    298.40     0.312  1277.0  165.4300  104.220  109.30
# ...  ..        ...       ...       ...     ...       ...      ...     ...
# 1106  0 2021-03-23   1727.96     0.339  2271.0  184.5022   92.336  108.72
# 1107  0 2021-03-30   1685.56     0.303  2103.0  184.8741   93.297  110.29
# 1108  0 2021-04-06   1743.28     0.440  2092.0  185.8393   92.335  109.88
# 1109  0 2021-04-13   1742.69     0.467  2140.0  188.1368   91.852  109.19
# 1110  0 2021-04-20   1779.72     0.492  2432.0  193.8035   91.147  108.09
#
#          GBP    Cl1  ...  EMUSTRUU  LF94TRUU     MXUS    MXEU     MXJP  \
# ...

# %%
# Plotting VIX and Anomalies Over Time
plt.figure(figsize=(12, 6))  # Adjusted figure size for better visualization

# Plotting the VIX time series
plt.plot(
    df['VIX'],
    label='VIX',
    color='blue',
    linewidth=2,
    alpha=0.8
)

# Highlighting anomalies with scatter points
plt.scatter(
    df[df['Y'] == 1].index,
    df[df['Y'] == 1]['VIX'],
    color='red',
    label='Anomaly',
    edgecolor='black',
    s=60  # Increased size for better visibility
)

# Adding title and axis labels with enhanced formatting
plt.title('VIX and Anomalies Over Time', fontsize=18, fontweight='bold', pad=15)
plt.xlabel('Index', fontsize=14)
plt.ylabel('VIX', fontsize=14)

# Adding gridlines for context
plt.grid(axis='both', linestyle='--', alpha=0.6)

# Adding a legend
plt.legend(fontsize=12, loc='upper left')

# Tight layout to avoid overlap
plt.tight_layout()

# Displaying the plot
plt.show()

# %%
# Data Visualization: XAU BGNL over Time
plt.figure(figsize=(12, 6))  # Wider figure for better display of time-series data

# Dynamically set axis limits
plt.xlim(0, df.shape[0])  # Full range of the data
plt.ylim(0, df['XAU BGNL'].max() * 1.1)  # Add 10% padding above max value for spacing

# Plotting the data
plt.plot(
    df['XAU BGNL'],
    color='gold',
    linewidth=2,
    label='XAU BGNL',
    alpha=0.8  # Slight transparency for better aesthetics
)

# Adding title and axis labels with improved formatting
plt.title('XAU BGNL Over Time', fontsize=20, fontweight='bold', pad=15)
plt.xlabel('Date', fontsize=14)
plt.ylabel('XAU BGNL', fontsize=14)

# Enhancing x-ticks for better readability
plt.xticks(
    range(0, df.shape[0], 50),  # Spacing x-ticks every 50 points
    df['Date'].iloc[::50],      # Show corresponding dates
    rotation=45,
    fontsize=10
)

# Adding a horizontal grid for better context
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Adding a legend to clarify the line representation
plt.legend(fontsize=12)

# Adjust layout to ensure everything fits well
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Data Visualization
plt.figure(figsize=(12, 6))  # Adjusted figure size for better visualization

# Set axis limits dynamically based on data range
plt.xlim(0, df.shape[0])
plt.ylim(0, df['BDIY'].max() * 1.1)  # Add 10% padding above max value for better spacing

# Plot the data
plt.plot(df['BDIY'], color='blue', linewidth=2, label='BDIY', alpha=0.8)

# Add title and axis labels with improved formatting
plt.title('BDIY Over Time', fontsize=20, fontweight='bold', pad=15)
plt.xlabel('Date', fontsize=14)
plt.ylabel('BDIY', fontsize=14)

# Customize x-ticks for readability
plt.xticks(
    range(0, df.shape[0], 50),  # Set ticks every 50 points
    df['Date'].iloc[::50],      # Use corresponding dates for labels
    rotation=45,
    fontsize=10
)

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Add a legend for clarity
plt.legend(fontsize=12)

# Display the plot
plt.tight_layout()  # Ensure elements fit well within the figure
plt.show()

# %%
# Since the plots above are very similar, try combining them into one loop to avoid redundant code
columns = ['VIX', 'XAU BGNL', 'BDIY']
for col in columns:
    plt.figure(figsize=(12,6))
    plt.plot(df[col], label=col)
    plt.scatter(df[df['Y'] == 1].index, df[df['Y'] == 1][col], color='red', label='Anomaly')
    plt.legend()
    plt.show()

# %%
# Set the grid dimensions
num_columns = 2  # Number of plots per row
num_rows = (len(df.columns) + num_columns - 1) // num_columns  # Calculate the required rows

# Set the figure size
plt.figure(figsize=(16, 4 * num_rows))

# Loop through each column and plot
for idx, column in enumerate(df.columns):
    if column in ['Date', 'Y']:  # Skip 'Date' and 'Y' columns
        continue

    plt.subplot(num_rows, num_columns, idx + 1)

    # Line plot for the column values
    plt.plot(df['Date'], df[column], label=column, color='blue', alpha=0.7)
    plt.title(f"{column} Over Time", fontsize=12)

    # Scatter plot for anomalies
    anomalies = df[df['Y'] == 1]
    plt.scatter(
        anomalies['Date'],  # X-axis is the 'Date' for anomalies
        anomalies[column],  # Y-axis is the column's values for anomalies
        color='red',
        label='Anomaly',
        edgecolor='black',
        s=50
    )

    # Set labels and ticks
    plt.xticks(rotation=45, fontsize=9)
    plt.xlabel("Date", fontsize=10)
    plt.ylabel(column, fontsize=10)
    plt.legend(fontsize=9)
    plt.grid(axis='y', linestyle='--', alpha=0.5)

# Adjust layout to avoid overlap
plt.tight_layout()
plt.show()

# %%
correlation_matrix = df.corr()
strong_correlations = correlation_matrix[(correlation_matrix.abs()> 0.8) & (correlation_matrix != 1)]
strong_correlations[['GT10', 'USGG30YR',  'USGG2YR', 'USGG3M', 'US0001M', 'GTDEM10Y', 'GTDEM30Y', 'GTDEM2Y', 'GTITL10YR', 'GTITL2YR', 'GTJPY30YR', 'GTJPY10YR', 'GTJPY2YR']]
# Out:
#                GT10  USGG30YR   USGG2YR    USGG3M   US0001M  GTDEM10Y  \
# Y               NaN       NaN       NaN       NaN       NaN       NaN
# Date      -0.881477 -0.932811       NaN       NaN       NaN -0.966089
# XAU BGNL  -0.893317 -0.868696       NaN       NaN       NaN -0.835680
# ECSURPUS        NaN       NaN       NaN       NaN       NaN       NaN
# BDIY            NaN       NaN       NaN       NaN       NaN       NaN
# CRY             NaN       NaN       NaN       NaN       NaN       NaN
# DXY             NaN       NaN       NaN       NaN       NaN       NaN
# JPY             NaN       NaN       NaN       NaN       NaN       NaN
# GBP             NaN       NaN       NaN       NaN       NaN       NaN
# Cl1             NaN       NaN       NaN       NaN       NaN       NaN
# VIX             NaN       NaN       NaN       NaN       NaN       NaN
# USGG30YR   0.966501       NaN       NaN       NaN       NaN  0.957880
# ...

# %%
strong_correlations[['MXUS', 'MXEU', 'MXIN', 'MXJP', 'MXCN','MXBR', 'MXRU', 'JPY', 'GBP']]
# Out:
#                MXUS      MXEU      MXIN      MXJP      MXCN      MXBR  \
# Y               NaN       NaN       NaN       NaN       NaN       NaN
# Date       0.833765       NaN  0.964150       NaN  0.872759       NaN
# XAU BGNL        NaN       NaN  0.831756       NaN  0.829659       NaN
# ECSURPUS        NaN       NaN       NaN       NaN       NaN       NaN
# BDIY            NaN       NaN       NaN       NaN       NaN       NaN
# CRY             NaN       NaN       NaN       NaN       NaN       NaN
# DXY             NaN       NaN       NaN       NaN       NaN       NaN
# JPY             NaN       NaN       NaN       NaN       NaN       NaN
# GBP             NaN       NaN       NaN       NaN       NaN       NaN
# Cl1             NaN       NaN       NaN       NaN       NaN  0.861036
# VIX             NaN       NaN       NaN       NaN       NaN       NaN
# USGG30YR        NaN       NaN -0.856734       NaN       NaN       NaN
# ...

# %%
# Subset columns of interest for two groups
group1_columns = ['GT10', 'USGG30YR', 'USGG2YR', 'USGG3M', 'US0001M',
                  'GTDEM10Y', 'GTDEM30Y', 'GTDEM2Y', 'GTITL10YR',
                  'GTITL2YR', 'GTJPY30YR', 'GTJPY10YR', 'GTJPY2YR']
group2_columns = ['MXUS', 'MXEU', 'MXIN', 'MXJP', 'MXCN', 'MXBR', 'MXRU', 'JPY', 'GBP']

# Filter correlation matrices for each group
group1_correlations = strong_correlations[group1_columns].loc[group1_columns]
group2_correlations = strong_correlations[group2_columns].loc[group2_columns]

# Define a function to visualize the correlation matrix as a heatmap
def plot_correlation_heatmap(correlation_data, title):
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        correlation_data,
        annot=True, fmt=".2f", cmap='coolwarm', cbar=True,
        linewidths=0.5, annot_kws={"fontsize": 10}
    )
    plt.title(title, fontsize=16, pad=15)
    plt.xticks(fontsize=10, rotation=45, ha='right')
    plt.yticks(fontsize=10)
    plt.tight_layout()
    plt.show()
# Visualize correlations for Group 1
plot_correlation_heatmap(
    group1_correlations,
    title="Strong Correlations in Group 1: Government Bonds and Yields"
)

# Visualize correlations for Group 2
plot_correlation_heatmap(
    group2_correlations,
    title="Strong Correlations in Group 2: Market Indices and Currencies"
)

# %% [markdown]
# JPY and GBP are excluded as they are reactive to market conditions rather than proactive indicators, potentially introducing noise to the model

# %%
for column in df.columns:
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
# Drop irrelevant columns
features = df.drop(columns = ['Y', 'Date'])
selected_features = df.drop(columns=['Y', 'Date','ECSURPUS', 'GTGBP30Y','MXJP', 'MXRU','Cl1', 'JPY', 'GBP', 'USGG2YR', 'USGG3M', 'US0001M', 'GTDEM30Y', 'GTDEM10Y', 'GTDEM2Y', 'GTITL10YR', 'GTITL2YR', 'GTJPY10YR', 'GTJPY2YR', 'GTGBP20Y', 'GTGBP2Y', 'LUMSTRUU','LMBITR', 'LUACTRUU','LF98TRUU', 'LG30TRUU', 'EMUSTRUU', 'LF94TRUU', 'MXBR', 'MXCN', 'Month'])

# Add exponential moving averages
selected_features['VIX_EMA'] = selected_features['VIX'].ewm(span=50, adjust=False).mean()
selected_features['BDIY_EMA'] = selected_features['BDIY'].ewm(span=50, adjust=False).mean()
selected_features['DXY_EMA'] = selected_features['DXY'].ewm(span=50, adjust=False).mean()
selected_features['VIX_MA'] = selected_features['VIX'].rolling(window=50).mean()
selected_features['BDIY_MA'] = selected_features['BDIY'].rolling(window=50).mean()

# Define target
target = df['Y']

# %%
selected_features['VIX_MA'] = selected_features['VIX_MA'].fillna(selected_features['VIX'])
selected_features['BDIY_MA'] = selected_features['BDIY_MA'].fillna(selected_features['BDIY'])

# %%
selected_features.columns
# Out:
# Index(['XAU BGNL', 'BDIY', 'CRY', 'DXY', 'VIX', 'USGG30YR', 'GT10', 'EONIA',
#        'GTITL30YR', 'GTJPY30YR', 'LP01TREU', 'MXUS', 'MXEU', 'MXIN', 'VIX_EMA',
#        'BDIY_EMA', 'DXY_EMA', 'VIX_MA', 'BDIY_MA'],
#       dtype='object')

# %%
from openai import OpenAI
import os
# from dotenv import load_dotenv
# load_dotenv()
from google.colab import userdata

# %%
# Initialize OpenAI client
groq_api = userdata.get('GROQ_API_KEY')
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=groq_api
)

# %%
# Asking LLM to explain the data
query_data = df.head(10)
system_prompt = '''You are an expert financial analyst with a strong background in machine learning and data analysis. You specialize in detecting anomalies in financial markets using structured data.

Your task is to analyze the following dataset and provide a detailed explanation.

1. **Explain Each Column**:
   - Provide a simple and concise explanation of each column header.
   - Describe its role in financial analysis and its potential impact on the market.

2. **Interrelation of Columns**:
   - Explain how the columns are related to each other (e.g., correlations or dependencies).
   - Discuss how these relationships can influence the occurrence of market anomalies.

3. **Market Anomaly Analysis**:
   - Assess whether each column has a direct or indirect effect on market crashes or anomalies.
   - Identify which columns are the most critical for understanding anomalies.

4. **Feature Selection for ML**:
   - Recommend the key columns that should be retained for training a machine learning model to detect anomalies.
   - Suggest if any columns should be dropped to improve model accuracy or reduce noise. Provide reasoning for your choices.

5. **Binary Target (Y)**:
   - The column `Y` is a binary indicator of whether a market anomaly occurred (1) or not (0). Discuss how the other columns might influence this target variable.

Here is the dataset for analysis:
{query_data}

Please provide actionable insights, recommendations for feature engineering, and reasoning grounded in financial and machine learning principles.'''

augmented_query = f"This is the data: {query_data}. The variable `Y` in the dataframe is a binary indicator of a market anomaly or not."

# %%
llm_response = client.chat.completions.create(
       model="llama-3.1-8b-instant",
       messages=[
           {"role": "system", "content": system_prompt},
           {"role": "user", "content": augmented_query}
       ]
   )

print(llm_response.choices[0].message.content)
# Out:
# **1. Explanation of Each Column**
#
# 1. **Y**: Binary target variable indicating whether a market anomaly occurred (1) or not (0).
# 2. **Date**: Date of the observation.
# 3. **XAU**: Gold price in USD.
# 4. **BGNL**: Gold futures price in British Pounds.
# 5. **EC SURPUS**: European Central Bank's (ECB) surplus/in deficit (data type is unclear).
# 6. **BDIY**: Baltic Dry Index (a measure of the cost of shipping bulk cargoes).
# 7. **CRY**: Gold futures price on the Commodity Exchange (COMEX) in USD.
# 8. **DXY**: US Dollar Index ( Dollar's value against 6 major currencies).
# 9. **JPY**: Japanese Yen price in USD.
# 10. **GBP**: Gold futures price on the London Bullion Market Association (LBMA) in British Pounds.
#
# 11. **Cl1**... **Cl36**: These columns contain data about exchange rates of various currencies (e.g., Russian Ruble, Chinese Rmb, Indian Rupee).
# ...

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is market anomaly detection?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Market anomaly detection refers to the process of identifying and analyzing unusual or unexpected events, trends, or patterns in financial markets. These anomalies can be irregular price movements, unusual trading volume, or unexpected changes in market sentiment.
#
# Market anomalies can be caused by a variety of factors, including:
#
# 1. **Error or noise**: Human errors, data entry mistakes, or technical issues can lead to anomalies.
# 2. **Unusual events**: Natural disasters, economic shocks, or major news events can cause unexpected price movements.
# 3. **Market inefficiencies**: Inefficient market mechanisms, such as arbitrage gaps or liquidity gaps, can lead to anomalies.
# 4. **Pattern recognition errors**: Overfitting or underfitting models can fail to capture market patterns, resulting in anomalies.
#
# ...

# %%
#pip install scikit-learn==1.2.2
#pip install imbalanced-learn==0.10.1

# %%
# Import libraries
import pickle
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import IsolationForest, RandomForestClassifier, VotingClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from sklearn.decomposition import PCA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.svm import SVC

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(
    selected_features, target, test_size=0.2, random_state=42, shuffle=False
)

# %%
X_train
# Out:
#      XAU BGNL    BDIY      CRY     DXY    VIX  USGG30YR   GT10  EONIA  \
# 0      283.25  1388.0  157.260  100.56  22.50     6.671  6.657  2.890
# 1      287.65  1405.0  165.010  101.86  21.50     6.747  6.748  3.030
# 2      287.15  1368.0  167.240  102.41  23.02     6.634  6.692  3.150
# 3      282.75  1311.0  166.850  104.92  23.45     6.423  6.619  3.300
# 4      298.40  1277.0  165.430  104.22  21.25     6.231  6.613  3.260
# ..        ...     ...      ...     ...    ...       ...    ...    ...
# 883   1156.94  1052.0  193.457  101.07  12.72     3.131  2.472 -0.348
# 884   1132.53   914.0  190.567  103.29  11.45     3.140  2.560 -0.354
# 885   1137.42   961.0  192.753  103.02  11.99     3.133  2.561 -0.356
# 886   1162.11   953.0  190.146  103.21  12.85     3.046  2.445 -0.329
# 887   1184.36   926.0  191.139  102.01  11.49     2.968  2.377 -0.356
#
#      GTITL30YR  GTJPY30YR  LP01TREU     MXUS    MXEU    MXIN    VIX_EMA  \
# ...

# %%
X_test
# Out:
#       XAU BGNL    BDIY       CRY      DXY    VIX  USGG30YR   GT10  EONIA  \
# 888    1213.29   922.0  195.1360  100.330  11.87    2.9320  2.326 -0.352
# 889    1212.73   886.0  194.9470  100.350  11.07    3.0490  2.466 -0.351
# 890    1210.59   800.0  192.0350   99.512  11.99    3.0610  2.454 -0.351
# 891    1234.75   714.0  191.3740  100.260  11.29    3.0180  2.394 -0.348
# 892    1224.01   685.0  192.2790  101.250  10.74    3.0580  2.471 -0.352
# ...        ...     ...       ...      ...    ...       ...    ...    ...
# 1106   1727.96  2271.0  184.5022   92.336  20.30    2.3264  1.622 -0.480
# 1107   1685.56  2103.0  184.8741   93.297  19.61    2.3687  1.706 -0.483
# 1108   1743.28  2092.0  185.8393   92.335  18.12    2.3230  1.658 -0.481
# 1109   1742.69  2140.0  188.1368   91.852  16.65    2.2939  1.616 -0.483
# 1110   1779.72  2432.0  193.8035   91.147  18.46    2.2619  1.565 -0.480
#
#       GTITL30YR  GTJPY30YR  LP01TREU     MXUS    MXEU     MXIN    VIX_EMA  \
# ...

# %%
# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled.shape
# Out:
# (888, 19)

# %%
X_test_scaled.shape
# Out:
# (223, 19)

# %%
type(X_test_scaled)
# Out:
# numpy.ndarray

# %%
# Apply PCA
pca = PCA(n_components=0.9)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# Add selected raw features to PCA components (if needed)
selected_columns_train = np.hstack((X_train_scaled[:, [4]], X_train_scaled[:, -5:]))
selected_columns_test = np.hstack((X_test_scaled[:, [4]], X_test_scaled[:, -5:]))

X_train_pca = np.hstack((X_train_pca, selected_columns_train))
X_test_pca = np.hstack((X_test_pca, selected_columns_test))

# %%
pca.explained_variance_ratio_
# Out:
# array([0.40693218, 0.23759097, 0.18087401, 0.06210467, 0.04139473])

# %%
X_train_pca.shape
# Out:
# (888, 11)

# %%
X_test_pca.shape
# Out:
# (223, 11)

# %%
def evaluate_and_save_model(model, X_train, X_test, y_train, y_test, model_filename):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("-------------")
    print(f"{model.__class__.__name__} Accuracy: {accuracy:.4f}")
    print(f"Classification Report:\n{classification_report(y_test, y_pred)}")
    print("-------------")

    # Save the model
    with open(model_filename, 'wb') as file:
        pickle.dump(model, file)
    print(f"Model saved as {model_filename}")

# %% [markdown]
# Logistic Regression

# %%
lr_model = LogisticRegression(random_state=42)
lr_model.fit(X_train_pca, y_train)
y_pred = lr_model.predict(X_test_pca)
evaluate_and_save_model(lr_model, X_train_pca, X_test_pca, y_train, y_test, 'logisticregression_model.pkl')
# Out:
# -------------
# LogisticRegression Accuracy: 0.8924
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       194
#            1       0.58      0.66      0.61        29
#
#     accuracy                           0.89       223
#    macro avg       0.76      0.79      0.78       223
# weighted avg       0.90      0.89      0.90       223
#
# -------------
# Model saved as logisticregression_model.pkl

# %% [markdown]
# Isolation Forest

# %%
iso_forest = IsolationForest(random_state=42, n_estimators=100, contamination=0.2)
iso_forest.fit(X_train_scaled)
# Out:
# IsolationForest(contamination=0.2, random_state=42)

# %%
scores = iso_forest.score_samples(X_train_scaled)

# %%
# plot histogram for the anomaly scores for the datapoints
plt.figure(figsize=(8,8))
plt.hist(scores, bins=50, color='blue', edgecolor='black', density=True, alpha=0.7)
plt.title('Anomaly Scores')
plt.xlabel('Anomaly Score')
plt.ylabel('Number of Data Points')
plt.show()

# %%
pred_test = iso_forest.predict(X_train_scaled)
pred_test = pred_test.reshape(-1, 1)
pred_test.shape
# Out:
# (888, 1)

# %%
isoforest_features =X_train.copy()
isoforest_features['Anomaly_scaled'] = pred_test
isoforest_features['Anomaly_scaled'] = isoforest_features['Anomaly_scaled'].replace({1: 0, -1: 1})

# %%
isoforest_features['Anomaly_scaled'].value_counts()
# Out:
# Anomaly_scaled
# 0    710
# 1    178
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.plot(isoforest_features['VIX'], label='VIX', color='blue')
plt.title(f"VIX over time with predicted anomalies")

plt.scatter(
    isoforest_features[isoforest_features['Anomaly_scaled'] == 1].index,  # X-axis is the index of the anomalies
    isoforest_features[isoforest_features['Anomaly_scaled'] == 1]['VIX'],  # Y-axis is the value of the column for anomalies
    color='red',
    label='Predicted Anomaly'
)
plt.scatter(
    df[df['Y'] == 1].index,  # X-axis is the index of the anomalies
    df[df['Y'] == 1]['VIX'],  # Y-axis is the value of the column for anomalies
    color='green',
    label='True Anomaly'
)
plt.xticks(range(0, df.shape[0], 50), df['Date'].iloc[::50], rotation=45)
plt.xlabel("Date", fontsize=10)
plt.ylabel('VIX', fontsize=10)
plt.legend()
plt.show()

# %% [markdown]
# Isolation Forest (with PCA)

# %%
pca_features = PCA(n_components=3)
selected_features_pca = pca_features.fit_transform(X_train_scaled)

# %%
isoforest_scaled_features = IsolationForest(random_state=42, n_estimators=100, contamination=0.2, max_samples='auto')
isoforest_scaled_features.fit(selected_features_pca)

pred_test_pca = isoforest_scaled_features.predict(selected_features_pca)
pred_test_pca = pred_test_pca.reshape(-1, 1)

isoforest_features['Anomaly_pca'] = pred_test_pca
isoforest_features['Anomaly_pca'] = isoforest_features['Anomaly_pca'].replace({1:0, -1:1})

# %%
isoforest_features['Anomaly_pca'].value_counts()
# Out:
# Anomaly_pca
# 0    710
# 1    178
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.plot(isoforest_features['VIX'], label='VIX', color='blue')
plt.title(f"VIX over time with predicted anomalies")

plt.scatter(
    isoforest_features[isoforest_features['Anomaly_scaled'] == 1].index,  # X-axis is the index of the anomalies
    isoforest_features[isoforest_features['Anomaly_scaled'] == 1]['VIX'],  # Y-axis is the value of the column for anomalies
    color='red',
    label='Predicted Anomaly(scaled)'
)
plt.scatter(
    isoforest_features[isoforest_features['Anomaly_pca'] == 1].index,  # X-axis is the index of the anomalies
    isoforest_features[isoforest_features['Anomaly_pca'] == 1]['VIX'],  # Y-axis is the value of the column for anomalies
    color='violet',
    label='Predicted Anomaly(pca)'
)
plt.scatter(
    df[df['Y'] == 1].index,  # X-axis is the index of the anomalies
    df[df['Y'] == 1]['VIX'],  # Y-axis is the value of the column for anomalies
    color='green',
    label='True Anomaly'
)
plt.xticks(range(0, df.shape[0], 50), df['Date'].iloc[::50], rotation=45)
plt.xlabel("Date", fontsize=10)
plt.ylabel('VIX', fontsize=10)
plt.legend()
plt.show()

# %% [markdown]
# XGBoost with GridSearch

# %%
param_grid = {'learning_rate': [0.01, 0.1, 0.5], 'n_estimators': [100, 200], 'subsample': [0.3, 0.5]}
xgb_model = xgb.XGBClassifier(random_state=42)
xgb_tuned = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=3)

# %%
evaluate_and_save_model(xgb_tuned, X_train_pca, X_test_pca, y_train, y_test, 'xgb_model_pca.pkl')
# Out:
# -------------
# GridSearchCV Accuracy: 0.9058
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       194
#            1       0.67      0.55      0.60        29
#
#     accuracy                           0.91       223
#    macro avg       0.80      0.76      0.78       223
# weighted avg       0.90      0.91      0.90       223
#
# -------------
# Model saved as xgb_model_pca.pkl

# %%
print("Best parameters found: ", xgb_tuned.best_params_)
print("Best score found: ", xgb_tuned.best_score_)
# Out:
# Best parameters found:  {'learning_rate': 0.01, 'n_estimators': 200, 'subsample': 0.3}
# Best score found:  0.7815315315315314

# %%
evaluate_and_save_model(xgb_tuned, X_train_scaled, X_test_scaled, y_train, y_test, 'xgb_model_scaled.pkl')
# Out:
# -------------
# GridSearchCV Accuracy: 0.9372
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97       194
#            1       1.00      0.52      0.68        29
#
#     accuracy                           0.94       223
#    macro avg       0.97      0.76      0.82       223
# weighted avg       0.94      0.94      0.93       223
#
# -------------
# Model saved as xgb_model_scaled.pkl

# %%
print("Best parameters found: ", xgb_tuned.best_params_)
print("Best score found: ", xgb_tuned.best_score_)
# Out:
# Best parameters found:  {'learning_rate': 0.01, 'n_estimators': 100, 'subsample': 0.5}
# Best score found:  0.7871621621621622

# %% [markdown]
# Improve Performance

# %% [markdown]
# Using SMOTE

# %%
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_train_pca, y_train)
evaluate_and_save_model(xgb_tuned, X_resampled, X_test_pca, y_resampled, y_test, 'xgb_model_smote.pkl')
# Out:
# -------------
# GridSearchCV Accuracy: 0.8879
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93       194
#            1       0.55      0.83      0.66        29
#
#     accuracy                           0.89       223
#    macro avg       0.76      0.86      0.80       223
# weighted avg       0.92      0.89      0.90       223
#
# -------------
# Model saved as xgb_model_smote.pkl

# %% [markdown]
# Voting Classifier

# %%
voting_clf = VotingClassifier(
    estimators=[
        ('xgboost', xgb.XGBClassifier(random_state=42)),
        ('rf', RandomForestClassifier(random_state=42)),
        ('svm', SVC(probability=True, random_state=42))
    ],
    voting='soft'
)
evaluate_and_save_model(voting_clf, X_resampled, X_test_pca, y_resampled, y_test, 'voting_clf_model.pkl')
# Out:
# -------------
# VotingClassifier Accuracy: 0.9103
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       194
#            1       0.70      0.55      0.62        29
#
#     accuracy                           0.91       223
#    macro avg       0.82      0.76      0.78       223
# weighted avg       0.90      0.91      0.91       223
#
# -------------
# Model saved as voting_clf_model.pkl

# %% [markdown]
# Deep Learning - Autoencoder

# %%
encoder = Sequential([
    LSTM(32, activation='relu', input_shape=(X_train_scaled.shape[1], 1))
])

decoder = Sequential([
    LSTM(32, activation='relu', input_shape=(32, 1)),
    Dense(X_train_scaled.shape[1])
])

autoencoder = Sequential([encoder, decoder])
autoencoder.compile(optimizer='adam', loss='mse')

# Reshape data for LSTM
X_train_lstm = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_lstm = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

autoencoder.fit(X_train_lstm, X_train_scaled, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 1.0039
# Epoch 2/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.0209
# Epoch 3/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2047.4393
# Epoch 4/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.9542
# Epoch 5/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.9528
# Epoch 6/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.9367
# Epoch 7/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9414
# Epoch 8/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9402
# Epoch 9/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9248
# Epoch 10/10
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.9492

# %%
autoencoder.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_4 (Sequential)            │ (None, 32)                  │           4,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_5 (Sequential)            │ (None, 19)                  │           4,979 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 27,995 (109.36 KB)
#  Trainable params: 9,331 (36.45 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 18,664 (72.91 KB)

# %%
loss = autoencoder.evaluate(X_test_scaled, y_test)  # Only loss
print(f"Test Loss: {loss}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0874
# Test Loss: 0.20909757912158966

# %% [markdown]
# Plot Anomalies

# %%
plt.figure(figsize=(14, 8))
plt.plot(isoforest_features['VIX'], label='VIX', color='blue')
plt.scatter(
    isoforest_features[isoforest_features['Anomaly_scaled'] == 1].index,
    isoforest_features[isoforest_features['Anomaly_scaled'] == 1]['VIX'],
    color='red',
    label='Anomaly'
)
plt.legend()
plt.show()
